# %%
from tqdm.notebook import tqdm

# %%
import hashlib
import os
import pathlib

import numpy as np
import pandas as pd
import requests
from tqdm.notebook import tqdm

import vasca.utils as vutils

# %% [markdown]
# # Read file manifest

# %%
# Read in URLs form the file manifest as DataFrame. Each column corresponds to a
# directory level but URLs have different depth. To handle this, the maximum number of
# levels are inferred by a look-ahead counting the number of levels line by line.

# Dynamically generate column names

# Input
try:
    manifest_path = pathlib.Path(__file__).parent / "pipeDirectoryListing.txt"
except NameError:
    # Handle jupyter notebook problem with __file__
    manifest_path = rf"{os.path.abspath('')}/pipeDirectoryListing.txt"
    



# Delimiter
data_file_delimiter = "/"

# The max column count a line in the file could have
largest_column_count = 0

# Count number of lines
lcounter = 0

# Loop the data lines
with open(manifest_path, "r") as temp_f:
    # Read the lines
    lines = temp_f.readlines()

    for line in lines:
        # Count the column count for the current line
        column_count = len(line.split(data_file_delimiter)) + 1

        # Set the new most column count
        largest_column_count = (
            column_count
            if largest_column_count < column_count
            else largest_column_count
        )

        lcounter += 1

# Generate column names (will be L0, L1, L2, ..., L<largest_column_count - 1>)
column_names = [f"L{i}" for i in range(0, largest_column_count)]

print("URL manifest info:")
print(f"    - Number of lines: {lcounter}")
print(f"    - Maximum number of directory levels: {largest_column_count}")
# Out:
# URL manifest info:
#     - Number of lines: 256225
#     - Maximum number of directory levels: 17

# %%
# Combine indidual level columns with full path
df_manifest = pd.concat(
    [
        pd.read_csv(manifest_path, header=None, delimiter=data_file_delimiter, names=column_names),
        pd.read_csv(manifest_path,delimiter=",", header=None, names= ["path"])
    ],
    axis=1
)

# %%
df_manifest
# L8: Drift scan (15 continous scans)
# L12: Visit (i.e, scan repetition, 20 visits on average)
# L13: image/catalog data ("svXX" corresponds to field number,
#      short scans (1−3, 13−15) consist of 9 fields,
#      long scans (4-12) coinsist of 14 fields each).
# Out:
#            L0  L1                 L2   L3     L4  L5    L6      L7  \
# 0       http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 1       http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 2       http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3       http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 4       http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# ...       ...  ..                ...  ...    ...  ..   ...     ...
# 256220  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 256221  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 256222  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 256223  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 256224  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
#
#                            L8 L9        L10       L11     L12  \
# 0       29200-KEPLER_SCAN_001  d  00-visits  0020-img  02-try
# 1       29200-KEPLER_SCAN_001  d  00-visits  0020-img  02-try
# 2       29200-KEPLER_SCAN_001  d  00-visits  0020-img  02-try
# 3       29200-KEPLER_SCAN_001  d  00-visits  0020-img  02-try
# 4       29200-KEPLER_SCAN_001  d  00-visits  0020-img  02-try
# ...                       ... ..        ...       ...     ...
# 256220  29206-KEPLER_SCAN_007  d  00-visits  0018-img  02-try
# 256221  29206-KEPLER_SCAN_007  d  00-visits  0018-img  02-try
# 256222  29206-KEPLER_SCAN_007  d  00-visits  0018-img  02-try
# 256223  29206-KEPLER_SCAN_007  d  00-visits  0018-img  02-try
# 256224  29206-KEPLER_SCAN_007  d  00-visits  0018-img  02-try
#
#                                                       L13  L14  L15  L16  \
# 0        KEPLER_SCAN_001_0020_sv06-nd-flag_varpix.fits.gz  NaN  NaN  NaN
# 1         KEPLER_SCAN_001_0020_sv03-nd-sexparams_orig.txt  NaN  NaN  NaN
# 2              KEPLER_SCAN_001_0020_sv08-nd-skybg.fits.gz  NaN  NaN  NaN
# 3       KEPLER_SCAN_001_0020_sv09-nd-cat_mch_rtastar.fits  NaN  NaN  NaN
# 4            KEPLER_SCAN_001_0020_sv02-nd-objmask_out.txt  NaN  NaN  NaN
# ...                                                   ...  ...  ...  ...
# 256220        KEPLER_SCAN_007_0018_sv09-nd-varpix.fits.gz  NaN  NaN  NaN
# 256221      KEPLER_SCAN_007_0018_sv12-nd-intbgsub.fits.gz  NaN  NaN  NaN
# 256222         KEPLER_SCAN_007_0018_sv08-nd-movie.fits.gz  NaN  NaN  NaN
# 256223             KEPLER_SCAN_007_0018_sv09-rtastar.fits  NaN  NaN  NaN
# 256224                KEPLER_SCAN_007_0018_sv01-scst.fits  NaN  NaN  NaN
#
#                                                      path
# 0       http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 1       http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 2       http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3       http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 4       http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# ...                                                   ...
# 256220  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 256221  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 256222  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 256223  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 256224  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
#
# [256225 rows x 18 columns]

# %%
np.unique(df_manifest["L8"])
# Out:
# array(['29200-KEPLER_SCAN_001', '29201-KEPLER_SCAN_002',
#        '29202-KEPLER_SCAN_003', '29203-KEPLER_SCAN_004',
#        '29204-KEPLER_SCAN_005', '29205-KEPLER_SCAN_006',
#        '29206-KEPLER_SCAN_007', '29207-KEPLER_SCAN_008',
#        '29208-KEPLER_SCAN_009', '29209-KEPLER_SCAN_010',
#        '29210-KEPLER_SCAN_011', '29211-KEPLER_SCAN_012',
#        '29212-KEPLER_SCAN_013', '29213-KEPLER_SCAN_014',
#        '29214-KEPLER_SCAN_015'], dtype=object)

# %%
df_manifest.query("L8 in ['29200-KEPLER_SCAN_001'] and L11 in ['0012-img']").query(
            "L13.str.contains('nd-count.fits|nd-rrhr.fits|nd-int.fits|nd-flags.fits|xd-mcat.fits')"
        ).sort_values("L13")
# Out:
#          L0  L1                 L2   L3     L4  L5    L6      L7  \
# 3116  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3084  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3058  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3282  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3306  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3198  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3264  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3197  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3235  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3128  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3139  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3181  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3226  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 2768  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3095  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3051  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3302  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3082  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3073  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3155  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3307  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3182  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3316  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3313  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3141  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3052  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3144  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
# 3146  http: NaN  archive.stsci.edu  pub  galex  KS  pipe  01-vsn
#
#                          L8 L9        L10       L11     L12  \
# 3116  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3084  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3058  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3282  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3306  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3198  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3264  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3197  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3235  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3128  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3139  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3181  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3226  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 2768  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3095  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3051  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3302  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3082  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3073  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3155  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3307  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3182  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3316  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3313  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3141  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3052  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3144  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
# 3146  29200-KEPLER_SCAN_001  d  00-visits  0012-img  02-try
#
#                                             L13  L14  L15  L16  \
# 3116    KEPLER_SCAN_001_0012_sv03-nd-flags.fits  NaN  NaN  NaN
# 3084   KEPLER_SCAN_001_0012_sv03-nd-int.fits.gz  NaN  NaN  NaN
# 3058  KEPLER_SCAN_001_0012_sv03-nd-rrhr.fits.gz  NaN  NaN  NaN
# 3282     KEPLER_SCAN_001_0012_sv03-xd-mcat.fits  NaN  NaN  NaN
# 3306    KEPLER_SCAN_001_0012_sv04-nd-flags.fits  NaN  NaN  NaN
# 3198   KEPLER_SCAN_001_0012_sv04-nd-int.fits.gz  NaN  NaN  NaN
# 3264  KEPLER_SCAN_001_0012_sv04-nd-rrhr.fits.gz  NaN  NaN  NaN
# 3197     KEPLER_SCAN_001_0012_sv04-xd-mcat.fits  NaN  NaN  NaN
# 3235    KEPLER_SCAN_001_0012_sv05-nd-flags.fits  NaN  NaN  NaN
# 3128   KEPLER_SCAN_001_0012_sv05-nd-int.fits.gz  NaN  NaN  NaN
# 3139  KEPLER_SCAN_001_0012_sv05-nd-rrhr.fits.gz  NaN  NaN  NaN
# 3181     KEPLER_SCAN_001_0012_sv05-xd-mcat.fits  NaN  NaN  NaN
# 3226    KEPLER_SCAN_001_0012_sv06-nd-flags.fits  NaN  NaN  NaN
# 2768   KEPLER_SCAN_001_0012_sv06-nd-int.fits.gz  NaN  NaN  NaN
# 3095  KEPLER_SCAN_001_0012_sv06-nd-rrhr.fits.gz  NaN  NaN  NaN
# 3051     KEPLER_SCAN_001_0012_sv06-xd-mcat.fits  NaN  NaN  NaN
# 3302    KEPLER_SCAN_001_0012_sv07-nd-flags.fits  NaN  NaN  NaN
# 3082   KEPLER_SCAN_001_0012_sv07-nd-int.fits.gz  NaN  NaN  NaN
# 3073  KEPLER_SCAN_001_0012_sv07-nd-rrhr.fits.gz  NaN  NaN  NaN
# 3155     KEPLER_SCAN_001_0012_sv07-xd-mcat.fits  NaN  NaN  NaN
# 3307    KEPLER_SCAN_001_0012_sv08-nd-flags.fits  NaN  NaN  NaN
# 3182   KEPLER_SCAN_001_0012_sv08-nd-int.fits.gz  NaN  NaN  NaN
# 3316  KEPLER_SCAN_001_0012_sv08-nd-rrhr.fits.gz  NaN  NaN  NaN
# 3313     KEPLER_SCAN_001_0012_sv08-xd-mcat.fits  NaN  NaN  NaN
# 3141    KEPLER_SCAN_001_0012_sv09-nd-flags.fits  NaN  NaN  NaN
# 3052   KEPLER_SCAN_001_0012_sv09-nd-int.fits.gz  NaN  NaN  NaN
# 3144  KEPLER_SCAN_001_0012_sv09-nd-rrhr.fits.gz  NaN  NaN  NaN
# 3146     KEPLER_SCAN_001_0012_sv09-xd-mcat.fits  NaN  NaN  NaN
#
#                                                    path
# 3116  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3084  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3058  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3282  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3306  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3198  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3264  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3197  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3235  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3128  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3139  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3181  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3226  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 2768  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3095  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3051  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3302  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3082  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3073  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3155  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3307  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3182  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3316  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3313  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3141  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3052  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3144  http://archive.stsci.edu/pub/galex/KS/pipe/01-...
# 3146  http://archive.stsci.edu/pub/galex/KS/pipe/01-...

# %%
np.unique(df_manifest["L11"])
# Out:
# array(['0001-img', '0002-img', '0003-img', '0004-img', '0005-img',
#        '0006-img', '0007-img', '0008-img', '0009-img', '0010-img',
#        '0011-img', '0012-img', '0013-img', '0014-img', '0015-img',
#        '0016-img', '0017-img', '0018-img', '0019-img', '0020-img',
#        '0021-img', '0022-img', '0023-img', '0024-img', '0025-img',
#        '0026-img', '0027-img', '0028-img', '0029-img'], dtype=object)

# %% [markdown]
# # Dowload data

# %%
def get_n_fields(id_scan):
    """
    Returns the number of sub-fields per drift scan:
    9 and 14 fields for the short scans (1−3 and 13−15) and long scans (4−12)
    """
    scan_num = int(id_scan.split("_")[-1])
    if scan_num <= 3 or scan_num >= 13:
        # short scans
        n_fields = 9
    elif scan_num >= 4 and scan_num <= 12:
        # long scans
        n_fields = 14
    else:
        raise ValueError(f"Unexpected scan ID '{id_scan}'.")
    
    return n_fields

# %%
# Settings

# Path to root data directory
root_data_dir = "/Users/julianschliwinski/GALEX_DS/galex_kepler"

# Refresh download (possibly overwrites existing files)
refresh = False

# %%
# Group by scan and visit
df_grpd = df_manifest.groupby(["L8", "L11"])

# %%
# %%time
# Counters
n_files = 0
n_vis = 0

# Loops over drift scans and visits
for i, (id_scan, id_visit) in tqdm(enumerate(df_grpd.groups.keys())):
    
    # Debugging
    # if i > 100: break
    if id_scan != '29200-KEPLER_SCAN_001': break
    #if id_visit != '0012-img': continue
    
    # Loops over fields (sv = "sub-visit")
    for k, id_sv in tqdm(
        enumerate([f'sv{num+1:02}' for num in range(get_n_fields(id_scan))]),
        total=get_n_fields(id_scan),
        desc=f"Fields ({id_scan}, {id_visit})"
    ):
        
        # Debugging
        if id_sv != "sv01": break
        
        # Selects fieles corresponding to field ID
        df_select = df_grpd.get_group((id_scan, id_visit)).query(
            "L13.str.contains('nd-count.fits|nd-rrhr.fits|nd-int.fits|nd-flags.fits|xd-mcat.fits') and L13.str.contains(@id_sv)"
        )
        df_select.sort_values("L13", inplace=True)

        # Download data
        if len(df_select)>0:
            
            if len(df_select) != 4:
                print(f"Warning: unexpected number of files {len(df_select)}")
                
            # Creat output directory path
            # Data is sorted by scan and visit (swap field and visit directories compared to web server)
            out_dir = f"{root_data_dir}/{id_scan}/{id_scan}_{id_sv}/{id_scan}_{id_sv}_{id_visit}"
            
            # Create the output directory if it doesn't exist
            os.makedirs(out_dir, exist_ok=True)
            
            # Loops over data files
            for idx, file_row in  df_select.iterrows():
                
                # File name
                file_name = file_row.L13
                
                file_url = file_row.path

                # Construct the output file path
                out_file_path = os.path.join(out_dir, file_name)

                # Download the file if it doesn't already exist or download is forced
                if not os.path.isfile(out_file_path) or refresh:
                    response = requests.get(file_url)
                    if response.status_code == 200:
                        with open(out_file_path, "wb") as f:
                            f.write(response.content)
                        print(f"Downloaded: {file_url}")
                    else:
                        print(f"Failed to download: {file_url}")
                else:
                    print(f"File exists: {file_url}")
            
            
            # counts number of files
            n_files += len(df_select)
    
    # Counts number of visits
    n_vis += 1

print(f"Downloaded {n_files/4:1.1f} exposures ({n_files} files) for {n_vis} visits.")
# Out:
# 0it [00:00, ?it/s]
# Fields (29200-KEPLER_SCAN_001, 0001-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0001-img/02-try/KEPLER_SCAN_001_0001_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0001-img/02-try/KEPLER_SCAN_001_0001_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0001-img/02-try/KEPLER_SCAN_001_0001_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0001-img/02-try/KEPLER_SCAN_001_0001_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0002-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0002-img/02-try/KEPLER_SCAN_001_0002_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0002-img/02-try/KEPLER_SCAN_001_0002_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0002-img/02-try/KEPLER_SCAN_001_0002_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0002-img/02-try/KEPLER_SCAN_001_0002_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0003-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0003-img/02-try/KEPLER_SCAN_001_0003_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0003-img/02-try/KEPLER_SCAN_001_0003_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0003-img/02-try/KEPLER_SCAN_001_0003_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0003-img/02-try/KEPLER_SCAN_001_0003_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0004-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0004-img/02-try/KEPLER_SCAN_001_0004_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0004-img/02-try/KEPLER_SCAN_001_0004_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0004-img/02-try/KEPLER_SCAN_001_0004_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0004-img/02-try/KEPLER_SCAN_001_0004_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0005-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0005-img/02-try/KEPLER_SCAN_001_0005_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0005-img/02-try/KEPLER_SCAN_001_0005_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0005-img/02-try/KEPLER_SCAN_001_0005_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0005-img/02-try/KEPLER_SCAN_001_0005_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0006-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0006-img/02-try/KEPLER_SCAN_001_0006_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0006-img/02-try/KEPLER_SCAN_001_0006_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0006-img/02-try/KEPLER_SCAN_001_0006_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0006-img/02-try/KEPLER_SCAN_001_0006_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0010-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0010-img/02-try/KEPLER_SCAN_001_0010_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0010-img/02-try/KEPLER_SCAN_001_0010_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0010-img/02-try/KEPLER_SCAN_001_0010_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0010-img/02-try/KEPLER_SCAN_001_0010_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0011-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0011-img/02-try/KEPLER_SCAN_001_0011_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0011-img/02-try/KEPLER_SCAN_001_0011_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0011-img/02-try/KEPLER_SCAN_001_0011_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0011-img/02-try/KEPLER_SCAN_001_0011_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0012-img):   0%|          | 0/9 [00:00<?, ?it/s]
# Fields (29200-KEPLER_SCAN_001, 0013-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0013-img/02-try/KEPLER_SCAN_001_0013_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0013-img/02-try/KEPLER_SCAN_001_0013_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0013-img/02-try/KEPLER_SCAN_001_0013_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0013-img/02-try/KEPLER_SCAN_001_0013_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0015-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0015-img/02-try/KEPLER_SCAN_001_0015_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0015-img/02-try/KEPLER_SCAN_001_0015_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0015-img/02-try/KEPLER_SCAN_001_0015_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0015-img/02-try/KEPLER_SCAN_001_0015_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0016-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0016-img/02-try/KEPLER_SCAN_001_0016_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0016-img/02-try/KEPLER_SCAN_001_0016_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0016-img/02-try/KEPLER_SCAN_001_0016_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0016-img/02-try/KEPLER_SCAN_001_0016_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0017-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0017-img/02-try/KEPLER_SCAN_001_0017_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0017-img/02-try/KEPLER_SCAN_001_0017_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0017-img/02-try/KEPLER_SCAN_001_0017_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0017-img/02-try/KEPLER_SCAN_001_0017_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0018-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0018-img/02-try/KEPLER_SCAN_001_0018_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0018-img/02-try/KEPLER_SCAN_001_0018_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0018-img/02-try/KEPLER_SCAN_001_0018_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0018-img/02-try/KEPLER_SCAN_001_0018_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0019-img):   0%|          | 0/9 [00:00<?, ?it/s]
# Fields (29200-KEPLER_SCAN_001, 0020-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0020-img/02-try/KEPLER_SCAN_001_0020_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0020-img/02-try/KEPLER_SCAN_001_0020_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0020-img/02-try/KEPLER_SCAN_001_0020_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0020-img/02-try/KEPLER_SCAN_001_0020_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0021-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0021-img/02-try/KEPLER_SCAN_001_0021_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0021-img/02-try/KEPLER_SCAN_001_0021_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0021-img/02-try/KEPLER_SCAN_001_0021_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0021-img/02-try/KEPLER_SCAN_001_0021_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0022-img):   0%|          | 0/9 [00:00<?, ?it/s]
# Fields (29200-KEPLER_SCAN_001, 0023-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0023-img/02-try/KEPLER_SCAN_001_0023_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0023-img/02-try/KEPLER_SCAN_001_0023_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0023-img/02-try/KEPLER_SCAN_001_0023_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0023-img/02-try/KEPLER_SCAN_001_0023_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0024-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0024-img/02-try/KEPLER_SCAN_001_0024_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0024-img/02-try/KEPLER_SCAN_001_0024_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0024-img/02-try/KEPLER_SCAN_001_0024_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0024-img/02-try/KEPLER_SCAN_001_0024_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0025-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0025-img/02-try/KEPLER_SCAN_001_0025_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0025-img/02-try/KEPLER_SCAN_001_0025_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0025-img/02-try/KEPLER_SCAN_001_0025_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0025-img/02-try/KEPLER_SCAN_001_0025_sv01-xd-mcat.fits
# Fields (29200-KEPLER_SCAN_001, 0026-img):   0%|          | 0/9 [00:00<?, ?it/s]
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0026-img/02-try/KEPLER_SCAN_001_0026_sv01-nd-flags.fits
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0026-img/02-try/KEPLER_SCAN_001_0026_sv01-nd-int.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0026-img/02-try/KEPLER_SCAN_001_0026_sv01-nd-rrhr.fits.gz
# File exists: http://archive.stsci.edu/pub/galex/KS/pipe/01-vsn/29200-KEPLER_SCAN_001/d/00-visits/0026-img/02-try/KEPLER_SCAN_001_0026_sv01-xd-mcat.fits
# Downloaded 19.0 exposures (76 files) for 22 visits.
# CPU times: user 375 ms, sys: 58.3 ms, total: 433 ms
# Wall time: 398 ms

# %%
# Average numb
n_fields = list()
for id_scan in np.unique(df_manifest["L8"]):
    
    num = len(np.unique(df_manifest.query("L8 == @id_scan")["L11"]))
    n_fields.append(num)

n_fields = np.array(n_fields)
n_fields.mean()
# Out:
# 19.866666666666667
